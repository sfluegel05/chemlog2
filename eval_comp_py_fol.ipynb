# %%
import os
import json
import pandas as pd

# %%
results_msol = None #todo
with open(os.path.join("results", "250131_1458", "classify_fol.json"), "r") as f:
    results_fol = pd.read_json(f)
with open(os.path.join("results", "250130_1000", "classify.json"), "r") as f:
    results_py = pd.read_json(f)

# %%
comp_df = results_fol.merge(results_py, on="chebi_id", suffixes=("_fol", "_py"))
comp_df
# Out:
#        chebi_id charge_category_fol  n_amino_acid_residues_fol  \
# 0         15429             NEUTRAL                          1
# 1         30236             NEUTRAL                          1
# 2         15571             NEUTRAL                          1
# 3         16830             NEUTRAL                          1
# 4         17790             NEUTRAL                          1
# ...         ...                 ...                        ...
# 39995     27984             NEUTRAL                          1
# 39996     77188             NEUTRAL                          1
# 39997    147844             NEUTRAL                          1
# 39998     16544             NEUTRAL                          1
# 39999     52892              CATION                          1
#
#                                        functional_groups proteinogenics_fol  \
# 0      {'amide_bond': [], 'amino_residue': [], 'carbo...                 []
# 1      {'amide_bond': [], 'amino_residue': [], 'carbo...                 []
# 2      {'amide_bond': [], 'amino_residue': [], 'carbo...                 []
# 3      {'amide_bond': [], 'amino_residue': [[0]], 'ca...                 []
# 4      {'amide_bond': [], 'amino_residue': [], 'carbo...                 []
# ...                                                  ...                ...
# 39995  {'amide_bond': [], 'amino_residue': [], 'carbo...                 []
# 39996  {'amide_bond': [[33, 34, 10]], 'amino_residue'...                 []
# 39997  {'amide_bond': [], 'amino_residue': [], 'carbo...                 []
# 39998  {'amide_bond': [[2, 3, 6], [4, 5, 7], [28, 27,...                 []
# 39999  {'amide_bond': [], 'amino_residue': [[17], [27...                 []
#
#        time_fol chebi_classes_fol  2,5-diketopiperazines_fol  \
# 0        0.0095                []                        NaN
# 1        0.0015                []                        NaN
# 2        0.0021                []                        NaN
# 3        0.0018                []                        NaN
# 4        0.0014                []                        NaN
# ...         ...               ...                        ...
# 39995    0.0587                []                        NaN
# 39996    0.0583                []                        NaN
# 39997    0.0231                []                        NaN
# 39998    0.0386                []                        NaN
# 39999    0.2336           [25697]                        NaN
#
#        emericellamide_fol charge_category_py  ...  proteinogenics_locations  \
# 0                     NaN            NEUTRAL  ...                        []
# 1                     NaN            NEUTRAL  ...                        []
# 2                     NaN            NEUTRAL  ...                        []
# 3                     NaN            NEUTRAL  ...                        []
# 4                     NaN            NEUTRAL  ...                        []
# ...                   ...                ...  ...                       ...
# 39995                 NaN            NEUTRAL  ...                        []
# 39996                 NaN            NEUTRAL  ...                        []
# 39997                 NaN            NEUTRAL  ...                        []
# 39998                 NaN            NEUTRAL  ...                        []
# 39999                 NaN             CATION  ...                        []
#
#       proteinogenics_locations_no_carboxy  \
# 0                                      []
# 1                                      []
# 2                                      []
# 3                                      []
# 4                                      []
# ...                                   ...
# 39995                                  []
# 39996                                  []
# 39997                                  []
# 39998                                  []
# 39999                                  []
#
#                             carboxy_residue amino_residue  \
# 0                                       NaN           NaN
# 1                                       NaN           NaN
# 2                                       NaN           NaN
# 3                                       NaN           NaN
# 4                                       NaN           NaN
# ...                                     ...           ...
# 39995                                   NaN           NaN
# 39996                        [[33, 34, 10]]          [10]
# 39997                                   NaN           NaN
# 39998  [[2, 3, 6], [4, 5, 7], [28, 27, 26]]    [6, 7, 26]
# 39999                                   NaN           NaN
#
#                                                   chunks longest_aa_chain  \
# 0                                                    NaN              NaN
# 1                                                    NaN              NaN
# 2                                                    NaN              NaN
# 3                                                    NaN              NaN
# 4                                                    NaN              NaN
# ...                                                  ...              ...
# 39995                                                NaN              NaN
# 39996  [[0, 1, 3, 4, 5, 9], [12, 13, 14, 16, 17, 21],...               []
# 39997                                                NaN              NaN
# 39998  [[0, 1, 2], [8, 10, 12, 14, 15], [41, 19, 21, ...               []
# 39999                                                NaN              NaN
#
#       2,5-diketopiperazines_py 2,5-diketopiperazines_atoms emericellamide_py  \
# 0                          NaN                         NaN               NaN
# 1                          NaN                         NaN               NaN
# 2                          NaN                         NaN               NaN
# 3                          NaN                         NaN               NaN
# 4                          NaN                         NaN               NaN
# ...                        ...                         ...               ...
# 39995                      NaN                         NaN               NaN
# 39996                      NaN                         NaN               NaN
# 39997                      NaN                         NaN               NaN
# 39998                      NaN                         NaN               NaN
# 39999                      NaN                         NaN               NaN
#
#       emericellamide_atoms
# 0                      NaN
# 1                      NaN
# 2                      NaN
# 3                      NaN
# 4                      NaN
# ...                    ...
# 39995                  NaN
# 39996                  NaN
# 39997                  NaN
# 39998                  NaN
# 39999                  NaN
#
# [40000 rows x 25 columns]

# %%
comp_df[comp_df["charge_category_fol"] != comp_df["charge_category_py"]]
# Out:
# Empty DataFrame
# Columns: [chebi_id, charge_category_fol, n_amino_acid_residues_fol, functional_groups, proteinogenics_fol, time_fol, chebi_classes_fol, 2,5-diketopiperazines_fol, emericellamide_fol, charge_category_py, n_amino_acid_residues_py, proteinogenics_py, time_py, chebi_classes_py, amide_bond, proteinogenics_locations, proteinogenics_locations_no_carboxy, carboxy_residue, amino_residue, chunks, longest_aa_chain, 2,5-diketopiperazines_py, 2,5-diketopiperazines_atoms, emericellamide_py, emericellamide_atoms]
# Index: []
#
# [0 rows x 25 columns]

# %%
comp_df[((comp_df["n_amino_acid_residues_fol"] >= 2) | (comp_df["n_amino_acid_residues_py"] >= 2)) & (comp_df["n_amino_acid_residues_fol"] != comp_df["n_amino_acid_residues_py"])]
# Out:
# Empty DataFrame
# Columns: [chebi_id, charge_category_fol, n_amino_acid_residues_fol, functional_groups, proteinogenics_fol, time_fol, chebi_classes_fol, 2,5-diketopiperazines_fol, emericellamide_fol, charge_category_py, n_amino_acid_residues_py, proteinogenics_py, time_py, chebi_classes_py, amide_bond, proteinogenics_locations, proteinogenics_locations_no_carboxy, carboxy_residue, amino_residue, chunks, longest_aa_chain, 2,5-diketopiperazines_py, 2,5-diketopiperazines_atoms, emericellamide_py, emericellamide_atoms]
# Index: []
#
# [0 rows x 25 columns]

# %%
comp_df[(comp_df["n_amino_acid_residues_fol"] > 1) & pd.Series([any([aa not in row["proteinogenics_fol"] for aa in row["proteinogenics_py"]]) or any(aa not in row["proteinogenics_py"] for aa in row["proteinogenics_fol"]) for _, row in comp_df.iterrows()])][["chebi_id", "proteinogenics_fol", "proteinogenics_py"]]
# Out:
#        chebi_id  proteinogenics_fol   proteinogenics_py
# 29198     53490     [L, M, fMet, F]        [fMet, L, F]
# 30599    194314     [L, M, fMet, F]        [fMet, L, F]
# 39859     66742  [P, A, I, D, M, F]  [I, F, A, P, D, A]

# %%
comp_df[["time_fol", "time_py"]].describe()
# Out:
#            time_fol       time_py
# count  76000.000000  76000.000000
# mean       0.041726      0.000202
# std        0.035455      0.000398
# min        0.009700      0.000000
# 25%        0.024700      0.000100
# 50%        0.032200      0.000200
# 75%        0.042800      0.000200
# max        0.463900      0.070300
